# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("1_earthquake_1995-2023.csv")

# %%
# df.drop(["Unnamed: 0.1","Unnamed: 0"],inplace = True,axis = 1)
df.head()
# Out:
#    Unnamed: 0                                     title  magnitude  cdi  mmi  \
# 0           0          M 6.5 - 42 km W of Sola, Vanuatu        6.5    7    4
# 1           1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5    8    6
# 2           2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6    7    5
# 3           3     M 7.2 - 98 km S of Sand Point, Alaska        7.2    6    6
# 4           4                  M 7.3 - Alaska Peninsula        7.3    0    5
#
#     alert  tsunami  sig net  nst  ...  magType    depth latitude  longitude  \
# 0   green        0  657  us  114  ...      mww  192.955   -13.88     167.16
# 1  yellow        0  775  us   92  ...      mww   69.727    12.81     -88.13
# 2   green        0  899  us   70  ...      mww  171.371   -38.19     -70.37
# 3   green        1  860  us  173  ...      mww   32.571    54.38    -160.70
# 4     NaN        1  820  at   79  ...       Mi   21.000    54.49    -160.80
#
#                 location      continent        country day month  year
# 0          Sola, Vanuatu        Oceania        Vanuatu  16     8  2023
# 1  Intipucá, El Salvador  North America    El Salvador  19     7  2023
# 2    Loncopué, Argentina  South America      Argentina  17     7  2023
# 3     Sand Point, Alaska  North America  United States  16     7  2023
# 4       Alaska Peninsula  North America  United States  16     7  2023
#
# [5 rows x 22 columns]

# %%
df[df["alert"].isna()].head()
# Out:
#     Unnamed: 0                                 title  magnitude  cdi  mmi  \
# 4            4              M 7.3 - Alaska Peninsula        7.3    0    5
# 62          62  M 6.5 - 71 km SE of Nikolski, Alaska        6.5    0    3
# 63          63  M 6.5 - 71 km SE of Nikolski, Alaska        6.5    0    3
# 65          65  M 6.7 - 91 km SE of Nikolski, Alaska        6.7    0    4
# 66          66  M 6.7 - 91 km SE of Nikolski, Alaska        6.7    0    4
#
#    alert  tsunami  sig net  nst  ...  magType  depth latitude  longitude  \
# 4    NaN        1  820  at   79  ...       Mi   21.0    54.49    -160.80
# 62   NaN        1  650  at   97  ...       Mi   37.0    52.50    -168.08
# 63   NaN        1  650  pt   23  ...       Mi   37.0    52.50    -168.08
# 65   NaN        1  691  at   50  ...       Mi   33.0    52.48    -167.74
# 66   NaN        1  691  pt   20  ...       Mi   33.0    52.48    -167.74
#
#             location      continent        country day month  year
# 4   Alaska Peninsula  North America  United States  16     7  2023
# 62  Nikolski, Alaska  North America  United States  11     1  2022
# 63  Nikolski, Alaska  North America  United States  11     1  2022
# 65  Nikolski, Alaska  North America  United States  11     1  2022
# 66  Nikolski, Alaska  North America  United States  11     1  2022
#
# [5 rows x 22 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Alert with CDI

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cdi = df[["cdi","alert"]].fillna("unknown")

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize = (10,10))
sns.countplot(x = "alert",data = df_cdi[df_cdi["cdi"]==0])

plt.title("Alert distribution for cdi = 0 ")
plt.show()

# %% [markdown]
# As we can see that for cmi = 0 (which means no community reported an earthquake) above 300 values are null in alert column, so it is safe to replace null values with "No alert" for cmi = 0.

# %%
df.loc[df['cdi'] == 0, 'alert'] = df.loc[df['cdi'] == 0, 'alert'].fillna('No alert')

# %%
alert_count = df_cdi.groupby(['cdi', 'alert']).size().reset_index(name='count')

# %%
alert_count
# Out:
#     cdi    alert  count
# 0     0    green     55
# 1     0  unknown    333
# 2     1    green     12
# 3     2    green     11
# 4     2  unknown      2
# 5     3    green     27
# 6     3  unknown     18
# 7     3   yellow      1
# 8     4    green     36
# 9     4  unknown     27
# 10    5    green     56
# 11    5      red      1
# 12    5  unknown     53
# 13    5   yellow      3
# 14    6    green     40
# 15    6  unknown     30
# 16    6   yellow      8
# 17    7    green     41
# 18    7   orange      2
# 19    7  unknown     46
# 20    7   yellow     11
# 21    8    green     33
# 22    8   orange     10
# 23    8      red      5
# 24    8  unknown     28
# 25    8   yellow     16
# 26    9    green     20
# 27    9   orange     12
# 28    9      red      7
# 29    9  unknown     11
# 30    9   yellow     19

# %%
# Create the plot
plt.figure(figsize=(10, 6))
sns.barplot(x='cdi', y='count', hue='alert', data=alert_count[alert_count["cdi"]!=0])

# Customize the plot
plt.title('Count of Alerts by CDI')
plt.xlabel('CDI')
plt.ylabel('Count of Alerts')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Alert with sig

# %%
df_al_sig = df[["sig","alert"]].fillna("unknown")
df_al_sig
# Out:
#      sig     alert
# 0    657     green
# 1    775    yellow
# 2    899     green
# 3    860     green
# 4    820  No alert
# ..   ...       ...
# 969  776  No alert
# 970  912  No alert
# 971  732  No alert
# 972  670  No alert
# 973  776  No alert
#
# [974 rows x 2 columns]

# %%
df_al_sig_mean= df_al_sig.groupby("alert").mean().reset_index()
df_al_sig_mean
# Out:
#       alert          sig
# 0  No alert   743.375375
# 1     green   776.181269
# 2    orange  1374.041667
# 3       red  2508.461538
# 4   unknown   919.441860
# 5    yellow  1014.706897

# %%
sns.barplot(x="alert",y="sig",data=df_al_sig_mean);

# %% [markdown]
# ## Alert with CDI = 1,2,3,4,5,6,7 and sig and Tsunami

# %%
df_al_sig_Tsu = df[df['cdi'].isin([1, 2, 3, 4,5,6,7])][['tsunami', 'alert',"cdi"]].fillna("unknown")

# %%
df_al_sig_Tsu
# Out:
#      tsunami    alert  cdi
# 0          0    green    7
# 2          0    green    7
# 3          1    green    6
# 5          1    green    5
# 6          1    green    4
# ..       ...      ...  ...
# 691        0  unknown    5
# 710        0  unknown    7
# 771        0  unknown    6
# 780        0  unknown    7
# 787        0  unknown    5
#
# [425 rows x 3 columns]

# %%
plt.figure(figsize=[10,9])

sns.countplot(x='alert',data=df_al_sig_Tsu,hue ="tsunami")
plt.xlabel("Alert")
plt.title("Alert count w.r.t tsunami")
plt.show()

# %% [markdown]
# More than 40 values for 'unknown' did not have a tsunami implying there was no alert issued

# %%
df_sig_mean = df_al_sig_Tsu[df_al_sig_Tsu["tsunami"] == 0].groupby(["cdi", "alert"]).size().reset_index(name="count")

df_sig_mean
# Out:
#     cdi    alert  count
# 0     1    green      1
# 1     2    green      2
# 2     2  unknown      1
# 3     3    green      8
# 4     3  unknown     18
# 5     3   yellow      1
# 6     4    green     16
# 7     4  unknown     27
# 8     5    green     15
# 9     5      red      1
# 10    5  unknown     53
# 11    5   yellow      2
# 12    6    green      6
# 13    6  unknown     30
# 14    6   yellow      3
# 15    7    green     12
# 16    7   orange      2
# 17    7  unknown     46
# 18    7   yellow      2

# %%
plt.figure(figsize=(12,8))

sns.barplot(x="alert", y="count", hue="cdi", data=df_sig_mean, palette="viridis")  # You can change "viridis" to any palette you like

plt.show()

# %% [markdown]
# ## Alert with magnitude

# %%
data_1 = df.fillna("unknown").groupby("alert")["magnitude"].mean().reset_index()
data_1
# Out:
#       alert  magnitude
# 0  No alert   6.936787
# 1     green   6.855891
# 2    orange   7.125000
# 3       red   7.323077
# 4   unknown   6.997674
# 5    yellow   7.006897

# %%
sns.barplot(x="alert",y="magnitude",data = data_1);

# %% [markdown]
# As we can see all the values are really close to each other thus we cant draw any conclusion out of this

# %%
data_1 = df.fillna("unknown").groupby("cdi")["magnitude"].mean().reset_index()
data_1
# Out:
#    cdi  magnitude
# 0    0   6.911727
# 1    1   6.858333
# 2    2   6.730769
# 3    3   6.765217
# 4    4   6.852381
# 5    5   6.884956
# 6    6   6.870513
# 7    7   6.904000
# 8    8   7.128261
# 9    9   7.272464

# %%
df.loc[(df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'] = df.loc[
    (df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'
].fillna('No alert')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  974 non-null    int64
#  1   title       974 non-null    object
#  2   magnitude   974 non-null    float64
#  3   cdi         974 non-null    int64
#  4   mmi         974 non-null    int64
#  5   alert       858 non-null    object
#  6   tsunami     974 non-null    int64
#  7   sig         974 non-null    int64
#  8   net         974 non-null    object
#  9   nst         974 non-null    int64
#  10  dmin        974 non-null    float64
#  11  gap         974 non-null    float64
#  12  magType     974 non-null    object
#  13  depth       974 non-null    float64
#  14  latitude    974 non-null    float64
#  15  longitude   974 non-null    float64
#  16  location    974 non-null    object
#  17  continent   974 non-null    object
#  18  country     974 non-null    object
#  19  day         974 non-null    int64
#  20  month       974 non-null    int64
#  21  year        974 non-null    int64
# dtypes: float64(6), int64(9), object(7)
# memory usage: 167.5+ KB

# %%
df.to_csv("2_earthquake_1995-2023.csv")
