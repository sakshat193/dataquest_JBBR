# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/PF/Projects/dataquest_JBBR-main/Datasets/1_earthquake_1995-2023.csv")

# %%
df.drop(["Unnamed: 0.1","Unnamed: 0"],inplace = True,axis = 1)
df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst  ...    gap  magType    depth  latitude  \
# 0    4   green        0  657  us  114  ...   25.0      mww  192.955    -13.88
# 1    6  yellow        0  775  us   92  ...   40.0      mww   69.727     12.81
# 2    5   green        0  899  us   70  ...   28.0      mww  171.371    -38.19
# 3    6   green        1  860  us  173  ...   36.0      mww   32.571     54.38
# 4    5     NaN        1  820  at   79  ...  172.8       Mi   21.000     54.49
#
#    longitude               location      continent        country        date  \
# 0     167.16          Sola, Vanuatu        Oceania        Vanuatu  2023-08-16
# 1     -88.13  Intipucá, El Salvador  North America    El Salvador  2023-07-19
# 2     -70.37    Loncopué, Argentina  South America      Argentina  2023-07-17
# 3    -160.70     Sand Point, Alaska  North America  United States  2023-07-16
# 4    -160.80       Alaska Peninsula  North America  United States  2023-07-16
#
#        time
# 0  12:47:00
# 1  00:22:00
# 2  03:05:00
# 3  06:48:00
# 4  06:48:00
#
# [5 rows x 21 columns]

# %%
df[df["alert"].isna()].head(30)
# Out:
#                                                  title  magnitude  \
# 4                             M 7.3 - Alaska Peninsula        7.3
# 62                M 6.5 - 71 km SE of Nikolski, Alaska        6.5
# 63                M 6.5 - 71 km SE of Nikolski, Alaska        6.5
# 65                M 6.7 - 91 km SE of Nikolski, Alaska        6.7
# 66                M 6.7 - 91 km SE of Nikolski, Alaska        6.7
# 140              M 6.6 - 34km NNE of Ndoi Island, Fiji        6.6
# 217                  M 7.1 - 1 km S of Matzaco, Mexico        7.1
# 431              M 7.5 - 110 km SW of Edna Bay, Alaska        7.5
# 432                 M 6.7 - 59 km SSW of Sola, Vanuatu        6.7
# 433                                  M 7.1 - Banda Sea        7.1
# 434                M 7.3 - 234 km SE of ?funato, Japan        7.3
# 435          M 6.5 - 32 km SW of Champerico, Guatemala        6.5
# 436               M 6.8 - 51 km NNE of Shwebo, Myanmar        6.8
# 438         M 7.8 - 206 km SW of Prince Rupert, Canada        7.8
# 439                                 M 6.5 - Costa Rica        6.5
# 440              M 6.6 - 163 km ENE of Tual, Indonesia        6.6
# 441         M 7.3 - 11 km WNW of San Agustín, Colombia        7.3
# 442          M 7.6 - 11 km ENE of Hojancha, Costa Rica        7.6
# 443           M 7.6 - 89 km E of Sulangan, Philippines        7.6
# 444  M 7.3 - 126 km S of Puerto El Triunfo, El Salv...        7.3
# 445            M 6.6 - 140 km WNW of Tobelo, Indonesia        6.6
# 446            M 7.7 - 156 km ENE of Poronaysk, Russia        7.7
# 447     M 6.5 - 105 km ESE of Kokopo, Papua New Guinea        6.5
# 448                   M 6.6 - 76 km W of Neiafu, Tonga        6.6
# 449          M 6.7 - 86 km SSE of Manokwari, Indonesia        6.7
# 450          M 6.8 - 140 km N of Lae, Papua New Guinea        6.8
# 451      M 6.7 - 22 km NW of Hacienda La Calera, Chile        6.7
# 452              M 7.0 - 69 km ENE of San Luis, Mexico        7.0
# 453            M 6.5 - 41 km NW of El Habillal, Mexico        6.5
# 454            M 7.1 - 23 km NE of Constitución, Chile        7.1
#
#             date_time  cdi  mmi alert  tsunami   sig net  nst  ...    gap  \
# 4    16-07-2023 06:48    0    5   NaN        1   820  at   79  ...  172.8
# 62   11-01-2022 12:39    0    3   NaN        1   650  at   97  ...  108.0
# 63   11-01-2022 12:39    0    3   NaN        1   650  pt   23  ...  208.8
# 65   11-01-2022 11:35    0    4   NaN        1   691  at   50  ...  126.0
# 66   11-01-2022 11:35    0    4   NaN        1   691  pt   20  ...  205.2
# 140  01-09-2019 15:54    2    3   NaN        1   671  us    0  ...   19.0
# 217  19-09-2017 18:14    9    8   NaN        0  1686  us    0  ...   23.0
# 431  05-01-2013 08:58    6    6   NaN        0  1425  ak    0  ...    0.0
# 432  21-12-2012 22:28    0    4   NaN        0   691  us  521  ...   13.7
# 433  10-12-2012 16:53    5    5   NaN        0   843  us  517  ...    8.7
# 434  07-12-2012 08:18    6    5   NaN        0  1014  us  918  ...   14.8
# 435  11-11-2012 22:14    4    5   NaN        0   708  us  598  ...   57.3
# 436  11-11-2012 01:12    7    6   NaN        0   795  us  391  ...   13.7
# 438  28-10-2012 03:04    8    7   NaN        0  1726  us  807  ...   42.7
# 439  24-10-2012 00:45    6    6   NaN        0   745  us  691  ...   34.4
# 440  12-10-2012 00:31    3    5   NaN        0   675  us  291  ...   17.7
# 441  30-09-2012 16:31    7    6   NaN        0  1221  us  934  ...   15.5
# 442  05-09-2012 14:42    8    7   NaN        0  1555  us  703  ...   34.3
# 443  31-08-2012 12:47    8    5   NaN        0  1115  us  682  ...   10.2
# 444  27-08-2012 04:37    5    5   NaN        0   994  us  417  ...   37.0
# 445  26-08-2012 15:05    4    5   NaN        0   678  us  497  ...   14.6
# 446  14-08-2012 02:59    7    4   NaN        0   941  us  862  ...   13.8
# 447  28-07-2012 20:03    5    6   NaN        0   653  us  576  ...   11.7
# 448  28-04-2012 10:08    4    5   NaN        0   675  us  529  ...   15.7
# 449  21-04-2012 01:16    0    7   NaN        0   691  us  370  ...   15.4
# 450  17-04-2012 07:13    6    5   NaN        0   732  us  597  ...   12.6
# 451  17-04-2012 03:50    0    7   NaN        0   691  us  518  ...   26.9
# 452  12-04-2012 07:15    7    7   NaN        0  1000  us  474  ...   95.9
# 453  11-04-2012 22:55    7    6   NaN        0  1171  us  599  ...   54.1
# 454  25-03-2012 22:37    7    7   NaN        0  1496  us  553  ...   15.2
#
#      magType  depth  latitude  longitude                        location  \
# 4         Mi   21.0     54.49    -160.80                Alaska Peninsula
# 62        Mi   37.0     52.50    -168.08                Nikolski, Alaska
# 63        Mi   37.0     52.50    -168.08                Nikolski, Alaska
# 65        Mi   33.0     52.48    -167.74                Nikolski, Alaska
# 66        Mi   33.0     52.48    -167.74                Nikolski, Alaska
# 140      mww  591.0    -20.36    -178.57               Ndoi Island, Fiji
# 217      mww   48.0     18.55     -98.49                 Matzaco, Mexico
# 431       mw    8.7     55.23    -134.86                Edna Bay, Alaska
# 432      mww  200.7    -14.34     167.29                   Sola, Vanuatu
# 433      mww  155.0     -6.53     129.82                       Banda Sea
# 434      mww   31.0     37.89     143.95                  ?funato, Japan
# 435      mww   20.0     14.13     -92.16           Champerico, Guatemala
# 436      mww   13.7     23.00      95.88                 Shwebo, Myanmar
# 438      mww   14.0     52.79    -132.10           Prince Rupert, Canada
# 439      mww   17.0     10.09     -85.30                      Costa Rica
# 440      mww   13.0     -4.89     134.03                 Tual, Indonesia
# 441      mww  170.0      1.93     -76.36           San Agustín, Colombia
# 442      mww   35.0     10.09     -85.32            Hojancha, Costa Rica
# 443      mww   28.0     10.81     126.64           Sulangan, Philippines
# 444      mww   28.0     12.14     -88.59  Puerto El Triunfo, El Salvador
# 445      mww   91.1      2.19     126.84               Tobelo, Indonesia
# 446      mww  583.2     49.80     145.06               Poronaysk, Russia
# 447      mww   41.0     -4.65     153.17        Kokopo, Papua New Guinea
# 448      mww  134.7    -18.68    -174.70                   Neiafu, Tonga
# 449      mww   16.0     -1.62     134.28            Manokwari, Indonesia
# 450      mww  198.0     -5.46     147.12           Lae, Papua New Guinea
# 451      mww   29.0    -32.62     -71.36       Hacienda La Calera, Chile
# 452      mww   13.0     28.70    -113.10                San Luis, Mexico
# 453      mwb   20.0     18.23    -102.69             El Habillal, Mexico
# 454      mww   40.7    -35.20     -72.22             Constitución, Chile
#
#          continent             country        date      time
# 4    North America       United States  2023-07-16  06:48:00
# 62   North America       United States  2022-01-11  12:39:00
# 63   North America       United States  2022-01-11  12:39:00
# 65   North America       United States  2022-01-11  11:35:00
# 66   North America       United States  2022-01-11  11:35:00
# 140        Oceania                Fiji  2019-09-01  15:54:00
# 217  North America              Mexico  2017-09-19  18:14:00
# 431  North America       United States  2013-01-05  08:58:00
# 432        Oceania             Vanuatu  2012-12-21  22:28:00
# 433           Asia           Indonesia  2012-12-10  16:53:00
# 434           Asia               Japan  2012-12-07  08:18:00
# 435  North America           Guatemala  2012-11-11  22:14:00
# 436           Asia             Myanmar  2012-11-11  01:12:00
# 438  North America              Canada  2012-10-28  03:04:00
# 439  North America          Costa Rica  2012-10-24  00:45:00
# 440           Asia           Indonesia  2012-10-12  00:31:00
# 441  South America            Colombia  2012-09-30  16:31:00
# 442  North America          Costa Rica  2012-09-05  14:42:00
# 443           Asia         Philippines  2012-08-31  12:47:00
# 444  North America         El Salvador  2012-08-27  04:37:00
# 445           Asia           Indonesia  2012-08-26  15:05:00
# 446         Europe  Russian Federation  2012-08-14  02:59:00
# 447        Oceania    Papua New Guinea  2012-07-28  20:03:00
# 448        Oceania               Tonga  2012-04-28  10:08:00
# 449           Asia           Indonesia  2012-04-21  01:16:00
# 450        Oceania    Papua New Guinea  2012-04-17  07:13:00
# 451  South America               Chile  2012-04-17  03:50:00
# 452  North America              Mexico  2012-04-12  07:15:00
# 453  North America              Mexico  2012-04-11  22:55:00
# 454  South America               Chile  2012-03-25  22:37:00
#
# [30 rows x 21 columns]

# %% [markdown]
# # Fixing Null values of alert column

# %% [markdown]
# ## Alert with CDI

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cdi = df[["cdi","alert"]].fillna("unknown")

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize = (10,10))
sns.countplot(x = "alert",data = df_cdi[df_cdi["cdi"]==0])

plt.title("Alert distribution for cdi = 0 ")
plt.show()

# %% [markdown]
# As we can see that for cmi = 0 (which means no community reported an earthquake) above 300 values are null in alert column, so it is safe to replace null values with "No alert" for cmi = 0.

# %%
df.loc[df['cdi'] == 0, 'alert'] = df.loc[df['cdi'] == 0, 'alert'].fillna('No alert')

# %%
alert_count = df_cdi.groupby(['cdi', 'alert']).size().reset_index(name='count')

# %%
alert_count
# Out:
#     cdi    alert  count
# 0     0    green     55
# 1     0  unknown    333
# 2     1    green     12
# 3     2    green     11
# 4     2  unknown      2
# 5     3    green     27
# 6     3  unknown     18
# 7     3   yellow      1
# 8     4    green     36
# 9     4  unknown     27
# 10    5    green     56
# 11    5      red      1
# 12    5  unknown     53
# 13    5   yellow      3
# 14    6    green     40
# 15    6  unknown     30
# 16    6   yellow      8
# 17    7    green     41
# 18    7   orange      2
# 19    7  unknown     46
# 20    7   yellow     11
# 21    8    green     33
# 22    8   orange     10
# 23    8      red      5
# 24    8  unknown     28
# 25    8   yellow     16
# 26    9    green     20
# 27    9   orange     12
# 28    9      red      7
# 29    9  unknown     11
# 30    9   yellow     19

# %%
# Create the plot
plt.figure(figsize=(10, 6))
sns.barplot(x='cdi', y='count', hue='alert', data=alert_count[alert_count["cdi"]!=0])

# Customize the plot
plt.title('Count of Alerts by CDI')
plt.xlabel('CDI')
plt.ylabel('Count of Alerts')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Unknown values are increasing till CDI = 5

# %% [markdown]
# ## Alert with sig

# %%
df_al_sig = df[["sig","alert"]].fillna("unknown")
df_al_sig
# Out:
#      sig     alert
# 0    657     green
# 1    775    yellow
# 2    899     green
# 3    860     green
# 4    820  No alert
# ..   ...       ...
# 969  776  No alert
# 970  912  No alert
# 971  732  No alert
# 972  670  No alert
# 973  776  No alert
#
# [974 rows x 2 columns]

# %%
df_al_sig_mean= df_al_sig.groupby("alert").mean().reset_index()
df_al_sig_mean
# Out:
#       alert          sig
# 0  No alert   743.375375
# 1     green   776.181269
# 2    orange  1374.041667
# 3       red  2508.461538
# 4   unknown   919.441860
# 5    yellow  1014.706897

# %%
sns.barplot(x="alert",y="sig",data=df_al_sig_mean);

# %% [markdown]
# ## Alert with CDI = 1,2,3,4,5,6 and sig and Tsunami

# %%
df_al_sig_Tsu = df[df['cdi'].isin([1, 2, 3, 4,5,6])][['tsunami', 'alert',"cdi"]].fillna("unknown")

# %%
df_al_sig_Tsu
# Out:
#      tsunami    alert  cdi
# 3          1    green    6
# 5          1    green    5
# 6          1    green    4
# 8          1    green    6
# 9          1    green    3
# ..       ...      ...  ...
# 685        0  unknown    5
# 689        0  unknown    5
# 691        0  unknown    5
# 771        0  unknown    6
# 787        0  unknown    5
#
# [325 rows x 3 columns]

# %%
plt.figure(figsize=[10,9])

sns.countplot(x='alert',data=df_al_sig_Tsu,hue ="tsunami")
plt.xlabel("Alert")
plt.title("Alert count w.r.t tsunami")
plt.show()

# %% [markdown]
# More than 40 values for 'unknown' did not have a tsunami implying there was no alert issued

# %%
df_sig_mean = df_al_sig_Tsu[df_al_sig_Tsu["tsunami"] == 0].groupby(["cdi", "alert"]).size().reset_index(name="count")

df_sig_mean
# Out:
#     cdi    alert  count
# 0     1    green      1
# 1     2    green      2
# 2     2  unknown      1
# 3     3    green      8
# 4     3  unknown     18
# 5     3   yellow      1
# 6     4    green     16
# 7     4  unknown     27
# 8     5    green     15
# 9     5      red      1
# 10    5  unknown     53
# 11    5   yellow      2
# 12    6    green      6
# 13    6  unknown     30
# 14    6   yellow      3

# %%
plt.figure(figsize=(12,8))

sns.barplot(x="alert", y="count", hue="cdi", data=df_sig_mean, palette="viridis")  # You can change "viridis" to any palette you like

plt.show()

# %% [markdown]
# The increasing number of "unknown" values up to CDI 5, in the absence of a tsunami, suggests that no alerts were issued for values below CDI 5 when a tsunami did not occur.

# %% [markdown]
# ## Alert with magnitude

# %%
data_1 = df.fillna("unknown").groupby("alert")["magnitude"].mean().reset_index()
data_1
# Out:
#       alert  magnitude
# 0  No alert   6.936787
# 1     green   6.855891
# 2    orange   7.125000
# 3       red   7.323077
# 4   unknown   6.997674
# 5    yellow   7.006897

# %%
sns.barplot(x="alert",y="magnitude",data = data_1);

# %% [markdown]
# As we can see all the values are really close to each other thus we cant draw any conclusion out of this

# %%
data_1 = df.fillna("unknown").groupby("cdi")["magnitude"].mean().reset_index()
data_1
# Out:
#    cdi  magnitude
# 0    0   6.911727
# 1    1   6.858333
# 2    2   6.730769
# 3    3   6.765217
# 4    4   6.852381
# 5    5   6.884956
# 6    6   6.870513
# 7    7   6.904000
# 8    8   7.128261
# 9    9   7.272464

# %%
#Filling values cor cdi 1,2,3,4,5 with tsunami == 0
df.loc[(df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'] = df.loc[
    (df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'
].fillna('No alert')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      974 non-null    object
#  1   magnitude  974 non-null    float64
#  2   date_time  974 non-null    object
#  3   cdi        974 non-null    int64
#  4   mmi        974 non-null    int64
#  5   alert      858 non-null    object
#  6   tsunami    974 non-null    int64
#  7   sig        974 non-null    int64
#  8   net        974 non-null    object
#  9   nst        974 non-null    int64
#  10  dmin       974 non-null    float64
#  11  gap        974 non-null    float64
#  12  magType    974 non-null    object
#  13  depth      974 non-null    float64
#  14  latitude   974 non-null    float64
#  15  longitude  974 non-null    float64
#  16  location   974 non-null    object
#  17  continent  974 non-null    object
#  18  country    974 non-null    object
#  19  date       974 non-null    object
#  20  time       974 non-null    object
# dtypes: float64(6), int64(5), object(10)
# memory usage: 159.9+ KB

# %%
df_al_sig = df[["sig","alert"]].fillna("unknown")
df_al_sig
# Out:
#      sig     alert
# 0    657     green
# 1    775    yellow
# 2    899     green
# 3    860     green
# 4    820  No alert
# ..   ...       ...
# 969  776  No alert
# 970  912  No alert
# 971  732  No alert
# 972  670  No alert
# 973  776  No alert
#
# [974 rows x 2 columns]

# %%
df_al_sig_mean= df_al_sig.groupby("alert").mean().reset_index()
df_al_sig_mean
# Out:
#       alert          sig
# 0  No alert   750.060185
# 1     green   776.181269
# 2    orange  1374.041667
# 3       red  2508.461538
# 4   unknown  1044.810345
# 5    yellow  1014.706897

# %%
sns.barplot(x="alert",y="sig",data=df_al_sig_mean);

# %% [markdown]
# The low values of SIG for "No alert" support our assumption that no alert was issued, as alerts are not triggered below the "green" level in the hierarchy. Additionally, the strong correlation between the alert column and SIG reinforces this, resulting in lower SIG values for instances with no alert.

# %% [markdown]
# # Conclusion
#
# We were succesfully able to Fill the Na values in the data set ,but there are still some nan values remaining thus to fill those values we will need to use a predictive model

# %%
df.to_csv("2_earthquake_1995-2023.csv")
