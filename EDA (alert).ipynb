# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("earthquake_1995-2023.csv")

# %%
#df.drop(["Unnamed: 0.1","Unnamed: 0"],inplace = True,axis = 1)
df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
#    latitude  longitude               location      continent    country
# 0  -13.8814   167.1580          Sola, Vanuatu            NaN    Vanuatu
# 1   12.8140   -88.1265  Intipucá, El Salvador            NaN        NaN
# 2  -38.1911   -70.3731    Loncopué, Argentina  South America  Argentina
# 3   54.3844  -160.6990     Sand Point, Alaska            NaN        NaN
# 4   54.4900  -160.7960       Alaska Peninsula            NaN        NaN

# %%
df[df["alert"].isna()].head(30)
# Out:
#                                                  title  magnitude  \
# 4                             M 7.3 - Alaska Peninsula        7.3
# 67                M 6.5 - 71 km SE of Nikolski, Alaska        6.5
# 68                M 6.5 - 71 km SE of Nikolski, Alaska        6.5
# 70                M 6.7 - 91 km SE of Nikolski, Alaska        6.7
# 71                M 6.7 - 91 km SE of Nikolski, Alaska        6.7
# 152              M 6.6 - 34km NNE of Ndoi Island, Fiji        6.6
# 232                  M 7.1 - 1 km S of Matzaco, Mexico        7.1
# 452              M 7.5 - 110 km SW of Edna Bay, Alaska        7.5
# 453                 M 6.7 - 59 km SSW of Sola, Vanuatu        6.7
# 454                                  M 7.1 - Banda Sea        7.1
# 455                M 7.3 - 234 km SE of ?funato, Japan        7.3
# 456          M 6.5 - 32 km SW of Champerico, Guatemala        6.5
# 457               M 6.8 - 51 km NNE of Shwebo, Myanmar        6.8
# 459         M 7.8 - 206 km SW of Prince Rupert, Canada        7.8
# 460                                 M 6.5 - Costa Rica        6.5
# 461              M 6.6 - 163 km ENE of Tual, Indonesia        6.6
# 462         M 7.3 - 11 km WNW of San Agustín, Colombia        7.3
# 463          M 7.6 - 11 km ENE of Hojancha, Costa Rica        7.6
# 464           M 7.6 - 89 km E of Sulangan, Philippines        7.6
# 465  M 7.3 - 126 km S of Puerto El Triunfo, El Salv...        7.3
# 466            M 6.6 - 140 km WNW of Tobelo, Indonesia        6.6
# 467            M 7.7 - 156 km ENE of Poronaysk, Russia        7.7
# 468     M 6.5 - 105 km ESE of Kokopo, Papua New Guinea        6.5
# 70   126.0      Mi   33.0   52.4800  -167.7360
# 71   205.2      Mi   33.0   52.4800  -167.7360
# 152   19.0     mww  591.0  -20.3641  -178.5700
# 232   23.0     mww   48.0   18.5499   -98.4887
# 452    0.0      mw    8.7   55.2280  -134.8590
# 453   13.7     mww  200.7  -14.3440   167.2860
# 454    8.7     mww  155.0   -6.5330   129.8250
# 455   14.8     mww   31.0   37.8900   143.9490
# 456   57.3     mww   20.0   14.1290   -92.1640
# 457   13.7     mww   13.7   23.0050    95.8850
# 459   42.7     mww   14.0   52.7880  -132.1010
# 460   34.4     mww   17.0   10.0860   -85.2980
# 461   17.7     mww   13.0   -4.8920   134.0300
# 462   15.5     mww  170.0    1.9290   -76.3620
# 463   34.3     mww   35.0   10.0850   -85.3150
# 464   10.2     mww   28.0   10.8110   126.6380
# 465   37.0     mww   28.0   12.1390   -88.5900
# 466   14.6     mww   91.1    2.1900   126.8370
# 467   13.8     mww  583.2   49.8000   145.0640
# 468   11.7     mww   41.0   -4.6510   153.1730
# 469   15.7     mww  134.7  -18.6850  -174.7050
# 470   15.4     mww   16.0   -1.6170   134.2760
# 471   12.6     mww  198.0   -5.4620   147.1170
# 472   26.9     mww   29.0  -32.6250   -71.3650
# 473   95.9     mww   13.0   28.6960  -113.1040
# 474   54.1     mwb   20.0   18.2290  -102.6890
# 477   15.2     mww   40.7  -35.2000   -72.2170
#
#                            location      continent           country
# 4                  Alaska Peninsula            NaN               NaN
# 67                 Nikolski, Alaska            NaN               NaN
# 68                 Nikolski, Alaska            NaN               NaN
# 70                 Nikolski, Alaska            NaN               NaN
# 71                 Nikolski, Alaska            NaN               NaN
# 152               Ndoi Island, Fiji            NaN              Fiji
# 232                 Matzaco, Mexico  North America            Mexico
# 452                Edna Bay, Alaska            NaN               NaN
# 453                   Sola, Vanuatu            NaN           Vanuatu
# 454                       Banda Sea            NaN         Indonesia
# 455                  ?funato, Japan            NaN               NaN
# 456           Champerico, Guatemala            NaN               NaN
# 457                 Shwebo, Myanmar           Asia           Myanmar
# 459           Prince Rupert, Canada  North America            Canada
# 460                      Costa Rica            NaN        Costa Rica
# 461                 Tual, Indonesia            NaN         Indonesia
# 462           San Agustín, Colombia  South America          Colombia
# 463            Hojancha, Costa Rica            NaN        Costa Rica
# 464           Sulangan, Philippines            NaN               NaN
# 465  Puerto El Triunfo, El Salvador            NaN               NaN
# 466               Tobelo, Indonesia            NaN         Indonesia
# 467               Poronaysk, Russia            NaN               NaN
# 468        Kokopo, Papua New Guinea            NaN  Papua New Guinea
# 469                   Neiafu, Tonga            NaN             Tonga
# 470            Manokwari, Indonesia            NaN         Indonesia
# 471           Lae, Papua New Guinea            NaN  Papua New Guinea
# 472       Hacienda La Calera, Chile  South America             Chile
# 473                San Luis, Mexico  North America            Mexico
# 474             El Habillal, Mexico  North America            Mexico
# 477             Constitución, Chile  South America             Chile

# %% [markdown]
# # EDA

# %% [markdown]
# ## Alert with CDI

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cdi = df[["cdi","alert"]].fillna("unknown")

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize = (10,10))
sns.countplot(x = "alert",data = df_cdi[df_cdi["cdi"]==0])

plt.title("Alert distribution for cdi = 0 ")
plt.show()

# %% [markdown]
# As we can see that for cmi = 0 (which means no community reported an earthquake) above 300 values are null in alert column, so it is safe to replace null values with "No alert" for cmi = 0.

# %%
df.loc[df['cdi'] == 0, 'alert'] = df.loc[df['cdi'] == 0, 'alert'].fillna('No alert')

# %%
alert_count = df_cdi.groupby(['cdi', 'alert']).size().reset_index(name='count')

# %%
alert_count
# Out:
#     cdi    alert  count
# 0     0    green     64
# 1     0  unknown    333
# 2     1    green     14
# 3     2    green     12
# 4     2  unknown      2
# 5     3    green     29
# 6     3  unknown     19
# 7     3   yellow      1
# 8     4    green     37
# 9     4  unknown     29
# 10    5    green     56
# 11    5      red      1
# 12    5  unknown     53
# 13    5   yellow      3
# 14    6    green     41
# 15    6  unknown     30
# 16    6   yellow      8
# 17    7    green     44
# 18    7   orange      2
# 19    7  unknown     46
# 20    7   yellow     11
# 21    8    green     34
# 22    8   orange     10
# 23    8      red      5
# 24    8  unknown     28
# 25    8   yellow     16
# 26    9    green     22
# 27    9   orange     12
# 28    9      red      7
# 29    9  unknown     11
# 30    9   yellow     20

# %%
# Create the plot
plt.figure(figsize=(10, 6))
sns.barplot(x='cdi', y='count', hue='alert', data=alert_count[alert_count["cdi"]!=0])

# Customize the plot
plt.title('Count of Alerts by CDI')
plt.xlabel('CDI')
plt.ylabel('Count of Alerts')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Alert with sig

# %%
df_al_sig = df[["sig","alert"]].fillna("unknown")
df_al_sig
# Out:
#      sig     alert
# 0    657     green
# 1    775    yellow
# 2    899     green
# 3    860     green
# 4    820  No alert
# ..   ...       ...
# 995  776  No alert
# 996  912  No alert
# 997  732  No alert
# 998  670  No alert
# 999  776  No alert
#
# [1000 rows x 2 columns]

# %%
df_al_sig_mean= df_al_sig.groupby("alert").mean().reset_index()
df_al_sig_mean
# Out:
#       alert          sig
# 0  No alert   743.375375
# 1     green   774.611898
# 2    orange  1374.041667
# 3       red  2508.461538
# 4   unknown   919.472477
# 5    yellow  1032.220339

# %%
sns.barplot(x="alert",y="sig",data=df_al_sig_mean);

# %% [markdown]
# ## Alert with CDI = 1,2,3,4,5,6,7 and sig and Tsunami

# %%
df_al_sig_Tsu = df[df['cdi'].isin([1, 2, 3, 4,5,6,7])][['tsunami', 'alert',"cdi"]].fillna("unknown")

# %%
df_al_sig_Tsu
# Out:
#      tsunami     alert  cdi
# 0          0     green    7
# 2          0     green    7
# 3          1     green    6
# 5          1     green    5
# 6          1     green    4
# ..       ...       ...  ...
# 717        0  No alert    5
# 736        0   unknown    7
# 797        0   unknown    6
# 806        0   unknown    7
# 813        0  No alert    5
#
# [438 rows x 3 columns]

# %%
plt.figure(figsize=[10,9])

sns.countplot(x='alert',data=df_al_sig_Tsu,hue ="tsunami")
plt.xlabel("Alert")
plt.title("Alert count w.r.t tsunami")
plt.show()

# %% [markdown]
# More than 40 values for 'unknown' did not have a tsunami implying there was no alert issued

# %%
df_sig_mean = df_al_sig_Tsu[df_al_sig_Tsu["tsunami"] == 0].groupby(["cdi", "alert"]).size().reset_index(name="count")

df_sig_mean
# Out:
#     cdi     alert  count
# 0     1     green      1
# 1     2  No alert      1
# 2     2     green      2
# 3     3  No alert     19
# 4     3     green      9
# 5     3    yellow      1
# 6     4  No alert     29
# 7     4     green     17
# 8     5  No alert     53
# 9     5     green     15
# 10    5       red      1
# 11    5    yellow      2
# 12    6     green      6
# 13    6   unknown     30
# 14    6    yellow      3
# 15    7     green     12
# 16    7    orange      2
# 17    7   unknown     46
# 18    7    yellow      2

# %%
plt.figure(figsize=(12,8))

sns.barplot(x="alert", y="count", hue="cdi", data=df_sig_mean, palette="viridis")  # You can change "viridis" to any palette you like

plt.show()

# %% [markdown]
# ## Alert with magnitude

# %%
data_1 = df.fillna("unknown").groupby("alert")["magnitude"].mean().reset_index()
data_1
# Out:
#       alert  magnitude
# 0  No alert   6.936787
# 1     green   6.860057
# 2    orange   7.125000
# 3       red   7.323077
# 4   unknown   7.006422
# 5    yellow   7.033898

# %%
sns.barplot(x="alert",y="magnitude",data = data_1);

# %% [markdown]
# As we can see all the values are really close to each other thus we cant draw any conclusion out of this

# %%
data_1 = df.fillna("unknown").groupby("cdi")["magnitude"].mean().reset_index()
data_1
# Out:
#    cdi  magnitude
# 0    0   6.909446
# 1    1   6.857143
# 2    2   6.742857
# 3    3   6.787755
# 4    4   6.871212
# 5    5   6.884956
# 6    6   6.870886
# 7    7   6.901942
# 8    8   7.126882
# 9    9   7.306944

# %%
df.loc[(df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'] = df.loc[
    (df['cdi'].isin([1, 2, 3, 4,5])) & (df['tsunami'] == 0), 'alert'
].fillna('No alert')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   magnitude  1000 non-null   float64
#  2   date_time  1000 non-null   object
#  3   cdi        1000 non-null   int64
#  4   mmi        1000 non-null   int64
#  5   alert      884 non-null    object
#  6   tsunami    1000 non-null   int64
#  7   sig        1000 non-null   int64
#  8   net        1000 non-null   object
#  9   nst        1000 non-null   int64
#  10  dmin       1000 non-null   float64
#  11  gap        1000 non-null   float64
#  12  magType    1000 non-null   object
#  13  depth      1000 non-null   float64
#  14  latitude   1000 non-null   float64
#  15  longitude  1000 non-null   float64
#  16  location   994 non-null    object
#  17  continent  284 non-null    object
#  18  country    651 non-null    object
# dtypes: float64(6), int64(5), object(8)
# memory usage: 148.6+ KB

# %%
df.to_csv("5_earthquake_1995-2023.csv")
